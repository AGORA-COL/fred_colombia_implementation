# %%
import time
import json
import requests

from selenium import webdriver
from bs4 import BeautifulSoup

from tqdm import tqdm
import pandas as pd
from datetime import datetime

# %% [markdown]
# # Get table details

# %% [markdown]
# ## Table headers

# %%
url = 'https://services1.arcgis.com/zBDE2yVH0hTpllh3/arcgis/rest/services/seguimiento_COVID_V3/FeatureServer/0?f=json'

response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Extract and print the list of fields
    fields = data.get('fields', [])
    for field in fields:
        #print(f"Name: {field['name']}, Type: {field['type']}, Alias: {field['alias']}")
        print(field['name'])
else:
    print("Failed to retrieve metadata from the service.")

# %% [markdown]
# ## Tables unique values

# %%
base_url = 'https://services1.arcgis.com/zBDE2yVH0hTpllh3/arcgis/rest/services/seguimiento_COVID_V3/FeatureServer/0/query'

# Function to get unique values for a field
def get_unique_values(field_name):
    params = {
        'f': 'json',
        'where': '1=1',  # A condition that's always true to get all features
        'outFields': field_name,
        'returnDistinctValues': 'true',
        'returnGeometry': 'false'
    }
    
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract unique values
    unique_values = set()
    for feature in data.get('features', []):
        attributes = feature.get('attributes', {})
        value = attributes.get(field_name)
        if value is not None:
            unique_values.add(value)
    
    return list(unique_values)

capacidad_values = get_unique_values('Capacidad')
departamento_values = get_unique_values('Departamento')
nombre_municipio_values = get_unique_values('Nombre_municipio')

print(f"Unique 'Capacidad' values: {capacidad_values}")
print(f"Unique 'Departamento' values: {departamento_values}")
print(f"Unique 'Nombre_municipio' values: {nombre_municipio_values}")
# Out:
# Unique 'Capacidad' values: ['Adultos', 'Cuidado Intensivo Adulto', 'Cuidado Intermedio Adulto']
# Unique 'Departamento' values: ['Total 88 - Archipiélago de San Andrés, Providencia y Santa Catalina', 'Total 91 - Amazonas', '18 - Caquetá', 'Total 85 - Casanare', 'Total 11 - Bogotá, D.C.', '08 - Atlántico', '11 - Bogotá, D.C.', 'Total 50 - Meta', 'Total 86 - Putumayo', 'Total 95 - Guaviare', 'Total 20 - Cesar', 'Total 15 - Boyacá', 'Total 17 - Caldas', 'Total 73 - Tolima', 'Total 19 - Cauca', 'Total 47 - Magdalena', '94 - Guainía', '86 - Putumayo', 'Total 05 - Antioquia', '44 - La Guajira', 'Total 41 - Huila', 'Total -1 - NO DEFINIDO', '73 - Tolima', 'Total 94 - Guainía', 'Total 08 - Atlántico', '68 - Santander', '20 - Cesar', '05 - Antioquia', '25 - Cundinamarca', '41 - Huila', '13 - Bolívar', 'Total 52 - Nariño', 'Total 63 - Quindio', '81 - Arauca', 'Total 25 - Cundinamarca', 'Total 99 - Vichada', '66 - Risaralda', '54 - Norte de Santander', '70 - Sucre', 'Total 18 - Caquetá', '-1 - NO DEFINIDO', '95 - Guaviare', 'Total 97 - Vaupés', '17 - Caldas', '23 - Córdoba', '50 - Meta', '88 - Archipiélago de San Andrés, Providencia y Santa Catalina', '15 - Boyacá', 'Total 66 - Risaralda', 'Total 27 - Chocó', 'Total 81 - Arauca', '63 - Quindio', '27 - Chocó', '91 - Amazonas', 'Total 54 - Norte de Santander', '97 - Vaupés', '47 - Magdalena', 'Total 44 - La Guajira', 'Total 70 - Sucre', 'Total 76 - Valle del Cauca', 'Total 13 - Bolívar', '52 - Nariño', '85 - Casanare', '19 - Cauca', 'Total 23 - Córdoba', '01 - País', '99 - Vichada', 'Total 68 - Santander', '76 - Valle del Cauca']
# Unique 'Nombre_municipio' values: ['', 'Puerto Santander', 'Toribio', 'Valledupar', 'Cajibío', 'Tenjo', 'Atrato', 'Onzaga', 'Pijao', 'Valle De San Juan', 'Santa Rosa De Osos', 'El Cocuy', 'Cunday', 'Canalete', 'Puracé', 'Purísima', 'Tierralta', 'Momil', 'Baranoa', 'San Juan De Arama', 'Guamo', 'Pivijay', 'Enciso', 'Puerto Lleras', 'Urrao', 'Amalfi', 'Aranzazu', 'Muzo', 'Guadalajara De Buga', 'Ciénaga De Oro', 'Linares', 'Carepa', 'Chimá', 'Cumaribo', 'Sabana De Torres', 'Bahía Solano', 'Tocancipá', 'Santa Bárbara', 'Cereté', 'Buriticá', 'Santa Isabel', 'Isnos', 'Mariquita', 'Falan', 'Zapayán', 'San Luis De Palenque', 'Montebello', 'San Benito Abad', 'Tello', 'Sipí', 'Puerto Arica', 'La Dorada', 'El Litoral Del San Juan', 'San Juan Nepomuceno', 'Condoto', 'San Andres De Tumaco', 'Planeta Rica', 'Puerto Nariño', 'Restrepo', 'Yalí', 'Arauquita', 'Ebéjico', 'La Gloria', 'Sabanas De San Angel', 'Istmina', 'Anserma', 'Sampués', 'Inzá', 'Gachetá', 'San Luis De Gaceno', 'Ortega', 'Agrado', 'San Vicente Del Caguán', 'La Mesa', 'La Plata', 'Quibdó', 'Peñol', 'Corozal', 'Viotá', 'Nechí', 'Cajicá', 'Valdivia', 'La Celia', 'Sasaima', 'Hatillo De Loba', 'Toca', 'Inírida', 'Santo Domingo', 'Yolombó', 'La Merced', 'Saldaña', 'Chameza', 'Dibulla', 'Rioblanco', 'Puerto Asís', 'Heliconia', 'Los Patios', 'Socha', 'Bucaramanga', 'Carmen Del Darien', 'Sopó', 'Coromoro', 'Villa De San Diego De Ubate', 'Sibaté', 'La Primavera', 'Barrancas', 'Juan De Acosta', 'La Sierra', 'Almaguer', 'Yondó', 'Fresno', 'Pamplona', 'Lejanías', 'Floridablanca', 'Facatativá', 'Támesis', 'Cerrito', 'Ovejas', 'Amagá', 'Palocabildo', 'Santa Marta', 'Fortul', 'Tuchín', 'Pailitas', 'Piedras', 'La Montañita', 'San Felipe', 'Ancuyá', 'San Carlos', 'El Cerrito', 'Icononzo', 'Paipa', 'Medio Atrato', 'Turbaco', 'Guaitarilla', 'Güicán', 'Tarqui', 'San Estanislao', 'Puebloviejo', 'Armenia', 'Guavatá', 'Capitanejo', 'Alpujarra', 'Puerto Guzmán', 'San Alberto', 'Cantagallo', 'San José De Miranda', 'Urumita', 'Uramita', 'Málaga', 'Garagoa', 'Guaranda', 'Santa Rosa', 'Salamina', 'Santafé De Antioquia', 'Paicol', 'Aratoca', 'Maicao', 'Algarrobo', 'El Tarra', 'Betania', 'Matanza', 'Entrerrios', 'Arboledas', 'Campoalegre', 'Agustín Codazzi', 'El Encanto', 'Honda', 'El Cantón Del San Pablo', 'Regidor', 'Valparaíso', 'Riohacha', 'Abejorral', 'Calima', 'Venecia', 'Barranca De Upía', 'Uribia', 'Patía', 'Orocué', 'Puerto Escondido', 'Caldas', 'Fuente De Oro', 'Bucarasica', 'Líbano', 'Recetor', 'Silvania', 'Sácama', 'El Dorado', 'Aguadas', 'San José De La Montaña', 'Santa Bárbara De Pinto', 'Bolívar', 'San Sebastián', 'Arenal', 'Zarzal', 'La Macarena', 'El Carmen De Viboral', 'Argelia', 'Abrego', 'Marulanda', 'Uribe', 'El Doncello', 'Colón', 'Aracataca', 'Nemocón', 'San Antero', 'Medina', 'Ciénaga', 'Puerto Boyacá', 'Sopetrán', 'Bagadó', 'Miraflores', 'Ibagué', 'La Tebaida', 'Pradera', 'Olaya', 'Sibundoy', 'Funza', 'Santa Rosalía', 'Coveñas', 'La Argentina', 'Betulia', 'Jardín', 'Aguazul', 'Sucre', 'Chinú', 'Guapi', 'Murillo', 'El Retén', 'Talaigua Nuevo', 'Cumbal', 'Piendamó', 'Sitionuevo', 'Albania', 'Encino', 'El Copey', 'Acevedo', 'Moñitos', 'Tolú Viejo', 'El Castillo', 'El Carmen De Chucurí', 'Anolaima', 'Nátaga', 'Guachetá', 'San Luis De Sincé', 'Barrancabermeja', 'Corinto', 'Guatavita', 'San Juan De Río Seco', 'La Ceja', 'San José Del Guaviare', 'Abriaquí', 'Ocaña', 'Andalucía', 'Bugalagrande', 'La Jagua De Ibirico', 'Caracolí', 'Valencia', 'Bello', 'Castilla La Nueva', 'Madrid', 'El Santuario', 'San Joaquín', 'Buenaventura', 'Cúcuta', 'Sahagún', 'El Roble', 'Cerro San Antonio', 'Roncesvalles', 'Belmira', 'Saboyá', 'Marinilla', 'Cotorra', 'Caimito', 'Cimitarra', 'Palmar De Varela', 'Hobo', 'Buenos Aires', 'Durania', 'Guadalupe', 'Galapa', 'Ulloa', 'Guacarí', 'San Andrés De Cuerquía', 'Cáceres', 'San Jerónimo', 'Mutatá', 'El Peñón', 'Puerto Carreño', 'Montenegro', 'Remolino', 'Soacha', 'Fomeque', 'San Juan Del Cesar', 'Tibú', 'Cali', 'Miriti - Paraná', 'Prado', 'Galán', 'Timaná', 'Colombia ...

# %% [markdown]
# # Get info

# %%
def format_date(date):
    return date.strftime('%Y-%m-%d %H:%M:%S')

# Function to query the API and return a DataFrame
def query_to_dataframe(start_date, end_date, fields):
    base_url = 'https://services1.arcgis.com/zBDE2yVH0hTpllh3/arcgis/rest/services/seguimiento_COVID_V3/FeatureServer/0/query'
    start_date_formatted = format_date(start_date)
    end_date_formatted = format_date(end_date)

    print(start_date_formatted, end_date_formatted)

    params = {
        'f': 'json',
        'where': f"(Fecha >= timestamp '{start_date_formatted}') AND (Fecha <= timestamp '{end_date_formatted}')",
        'outFields': ','.join(fields),
        'returnGeometry': 'false',
        'outSR': '4326',
        'resultOffset': 0,
        'resultRecordCount': 2000  # We are limited to 2000 lenght tables
    }

    data_flattened = []
    #while True:
    for i in tqdm(range(100000000000000)):
        response = requests.get(base_url, params=params)
        response_json = response.json()
        features = response_json.get('features', [])
        if not features:
            break  # No more data to retrieve
        data_flattened.extend(features)
        params['resultOffset'] += params['resultRecordCount']

    df = pd.DataFrame([feature['attributes'] for feature in data_flattened])

    if 'Fecha' in df.columns:
        df['Fecha'] = pd.to_datetime(df['Fecha'], unit='ms')

    return df

start_date = datetime(2020, 1, 1)
end_date = datetime(2023, 12, 31)
fields = [
    'Fecha',
    'Concepto_Desc',
    'Capacidad',
    'Departamento',
    'Municipio',
    'COVID_confirmados',
    'COVID_sospechosos',
    'No_COVID',
    'Total_camas',
    'Camas_disponibles',
    'PCD',
    'Total_casos_COVID',
    'Porcentaje_camas_disponibles',
    'Ocupación_total_COVID',
    'Nombre_departamento',
    'Nombre_municipio',
    'PrefijoDpto',
    'PrefijoMpio',
    'FID',
    'ID_CARGA'
]

df = query_to_dataframe(start_date, end_date, fields)
# Out:
# 2020-01-01 00:00:00 2023-12-31 00:00:00
#   0%|          | 720/100000000000000 [11:37<26901754966:39:46,  1.03it/s]

# %%
## Save info
df.to_csv('../output_files/camas_uci_colombia.csv', index=False)

# %%
departamentos_colombia = ['08 - Atlántico', '11 - Bogotá, D.C.', '13 - Bolívar',
       '15 - Boyacá', '20 - Cesar', '05 - Antioquia', '25 - Cundinamarca',
       '19 - Cauca', '23 - Córdoba', '27 - Chocó', '17 - Caldas',
       '18 - Caquetá', '86 - Putumayo', '47 - Magdalena', '52 - Nariño',
       '50 - Meta', '73 - Tolima', '85 - Casanare', '68 - Santander',
       '41 - Huila', '94 - Guainía', '63 - Quindio', '70 - Sucre',
       '76 - Valle del Cauca', '66 - Risaralda', '44 - La Guajira',
       '54 - Norte de Santander',
       '88 - Archipiélago de San Andrés, Providencia y Santa Catalina',
       '81 - Arauca', '91 - Amazonas', '99 - Vichada', '95 - Guaviare',
       '97 - Vaupés']

df[df.Departamento.isin(departamentos_colombia)]
# Out:
#                       Fecha Concepto_Desc Capacidad    Departamento  \
# 0       2020-07-01 12:00:00         CAMAS   Adultos  08 - Atlántico
# 1       2020-07-01 12:00:00         CAMAS   Adultos  08 - Atlántico
# 2       2020-07-01 12:00:00         CAMAS   Adultos  08 - Atlántico
# 3       2020-07-01 12:00:00         CAMAS   Adultos  08 - Atlántico
# 4       2020-07-01 12:00:00         CAMAS   Adultos  08 - Atlántico
# ...                     ...           ...       ...             ...
# 1438854 2023-11-26 12:00:00         CAMAS   Adultos     73 - Tolima
# 1438855 2023-11-26 12:00:00         CAMAS   Adultos     73 - Tolima
# 1438856 2023-11-26 12:00:00         CAMAS   Adultos     73 - Tolima
# 1438857 2023-11-26 12:00:00         CAMAS   Adultos     73 - Tolima
# 1438858 2023-11-26 12:00:00         CAMAS   Adultos     73 - Tolima
#
#                         Municipio  COVID_confirmados  COVID_sospechosos  \
# 0        08137 - Campo De La Cruz                0.0                0.0
# 1                  08296 - Galapa                0.0                0.0
# 2          08372 - Juan De Acosta                0.0                0.0
# 3                 08421 - Luruaco                0.0                0.0
# 4                 08433 - Malambo                1.0                1.0
# ...                           ...                ...                ...
# 1438854             73319 - Guamo                0.0                0.0
# 1438855            73347 - Herveo                0.0                0.0
# 1438856             73349 - Honda                0.0                0.0
# 1438857          73352 - Icononzo                0.0                0.0
# 1438858            73408 - Lérida                0.0                0.0
#
#          No_COVID  Total_camas  Camas_disponibles       PCD  \
# 0             0.0          7.0                7.0  1.000000
# 1             0.0         10.0               10.0  1.000000
# 2             0.0          6.0                6.0  1.000000
# 3             4.0         11.0                7.0  0.636364
# 4             0.0         47.0               45.0  0.957447
# ...           ...          ...                ...       ...
# 1438854       0.0         10.0               10.0  1.000000
# 1438855       0.0          4.0                4.0  1.000000
# 1438856      27.0         34.0                7.0  0.205882
# 1438857       0.0          4.0                4.0  1.000000
# 1438858      20.0         20.0                0.0  0.000000
#
#          Total_casos_COVID  Porcentaje_camas_disponibles  \
# 0                      0.0                        1.0000
# 1                      0.0                        1.0000
# 2                      0.0                        1.0000
# 3                      0.0                        0.6364
# 4                      2.0                        0.9574
# ...                    ...                           ...
# 1438854                0.0                        1.0000
# 1438855                0.0                        1.0000
# 1438856                0.0                        0.2059
# 1438857                0.0                        1.0000
# 1438858                0.0                        0.0000
#
#          Ocupación_total_COVID Nombre_departamento  Nombre_municipio  \
# 0                          0.0           Atlántico  Campo De La Cruz
# 1                          0.0           Atlántico            Galapa
# 2                          0.0           Atlántico    Juan De Acosta
# 3                          0.0           Atlántico           Luruaco
# 4                          2.0           Atlántico           Malambo
# ...                        ...                 ...               ...
# 1438854                    0.0              Tolima             Guamo
# 1438855                    0.0              Tolima            Herveo
# 1438856                    0.0              Tolima             Honda
# 1438857                    0.0              Tolima          Icononzo
# 1438858                    0.0              Tolima            Lérida
#
#                  PrefijoDpto      PrefijoMpio      FID  ID_CARGA
# 0        el departamento de   , municipio de         1       NaN
# 1        el departamento de   , municipio de         2       NaN
# 2        el departamento de   , municipio de         3       NaN
# 3        el departamento de   , municipio de         4       NaN
# 4        el departamento de   , municipio de         5       NaN
# ...                      ...              ...      ...       ...
# 1438854  el departamento de   , municipio de   1491233       NaN
# 1438855  el departamento de   , municipio de   1491234       NaN
# 1438856  el departamento de   , municipio de   1491235       NaN
# 1438857  el departamento de   , municipio de   1491236       NaN
# 1438858  el departamento de   , municipio de   1491237       NaN
#
# [1431763 rows x 20 columns]
